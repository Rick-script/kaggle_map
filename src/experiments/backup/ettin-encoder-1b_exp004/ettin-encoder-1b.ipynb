# %%
# Google Colabでの設定
google_colab = True

if google_colab:
    from google.colab import drive
    from google.colab import userdata

    drive.mount("/content/drive")

    # ディレクトリ移動
    # %cd /content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp004
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp004

# %%
import os
import gc
import time
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

import torch
import wandb
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer

# %%
class CFG:
    """実験設定管理クラス"""

    # ============== 実験情報 =============
    comp_name = "kaggle_map"
    exp_name = "ettin-encoder-1b_exp004"
    model_name = "jhu-clsp/ettin-encoder-1b"

    # ============== ファイルパス設定 =============
    comp_dir_path = "../../kaggle/input/"
    comp_dataset_path = f"{comp_dir_path}/map-charting-student-math-misunderstandings/"
    output_dir_path = "output/"
    log_dir_path = "logs/"

    # ============== モデル設定 =============
    max_len = 256

    num_train_epochs = 10
    per_device_train_batch_size = 32
    gradient_accumulation_steps = 1
    per_device_eval_batch_size = 64
    optim_type = "adamw_torch"
    learning_rate = 5e-5
    lr_scheduler_type = "cosine"
    warmup_steps = 50
    weight_decay = 0.01

    # ============== その他設定 =============
    seed = 42
    device = torch.device("cuda")

# %%
# 乱数固定
def set_seed(seed=None, cudnn_deterministic=True):
    if seed is None:
        seed = 42

    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = cudnn_deterministic
    torch.backends.cudnn.benchmark = False

def make_dirs(cfg):
    for dir in [cfg.output_dir_path, cfg.log_dir_path]:
        os.makedirs(dir, exist_ok=True)

def cfg_init(cfg):
    set_seed(cfg.seed)
    make_dirs(cfg)

# %% [markdown]
# # LLMの学習

# %% [markdown]
# ## データの読み込み

# %%
def add_folds_by_qid_cat_misc(df, n_splits=5, random_state=42, fallback="pair"):
    s_qid  = df["QuestionId"].astype(str).fillna("NA")
    s_cat  = df["Category"].astype(str).fillna("NA")
    s_misc = df["Misconception"].astype(str).fillna("NA")

    y_triple = s_qid + "|" + s_cat + "|" + s_misc
    y_pair   = s_cat + "|" + s_misc

    cnt = y_triple.value_counts()
    if (cnt < n_splits).any():
        if fallback == "pair":
            rare = y_triple.map(cnt) < n_splits
            y = np.where(rare, y_pair, y_triple)
        elif fallback == "category":
            rare = y_triple.map(cnt) < n_splits
            y = np.where(rare, s_cat, y_triple)
        elif fallback == "none":
            y = y_triple
        else:
            raise ValueError("fallback は 'pair' / 'category' / 'none' のいずれかにしてください。")
    else:
        y = y_triple

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    folds = np.full(len(df), -1, dtype=int)
    for fold, (_, val_idx) in enumerate(skf.split(np.zeros(len(df)), y)):
        folds[val_idx] = fold

    out = df.copy()
    out["fold"] = folds
    return out

# %%
# データ読み込み
train = pd.read_csv(f"{CFG.comp_dataset_path}/train.csv")
train = add_folds_by_qid_cat_misc(train, n_splits=5, random_state=42, fallback="pair")

train.Misconception = train.Misconception.fillna("NA")
train["target"] = train.Category + ":" + train.Misconception

# ラベルエンコード
le = LabelEncoder()
train["label"] = le.fit_transform(train["target"])

n_classes = len(le.classes_)
print(f"訓練データの形状: {train.shape} - {n_classes}個のターゲットクラス")
train.head(3)
# Out:
# 訓練データの形状: (36696, 10) - 65個のターゲットクラス
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
#    row_id  QuestionId                                       QuestionText  \
# 0       0       31772  What fraction of the shape is not shaded? Give...
# 1       1       31772  What fraction of the shape is not shaded? Give...
# 2       2       31772  What fraction of the shape is not shaded? Give...
#
#            MC_Answer                                 StudentExplanation  \
# 0  \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1  \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2  \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
#
#        Category Misconception  fold           target  label
# 0  True_Correct            NA     1  True_Correct:NA     37
# 1  True_Correct            NA     4  True_Correct:NA     37
# 2  True_Neither            NA     2  True_Neither:NA     64

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
# 正解ラベルの作成
idx = train.apply(lambda row: row.Category.split("_")[0], axis=1) == "True"
correct = train.loc[idx].copy()
correct["c"] = correct.groupby(["QuestionId", "MC_Answer"]).MC_Answer.transform("count")
correct = correct.sort_values("c", ascending=False)
correct = correct.drop_duplicates(["QuestionId"])
correct = correct[["QuestionId", "MC_Answer"]]
correct["is_correct"] = 1

# 正解ラベルを訓練データにマージ
train = train.merge(correct, on=["QuestionId", "MC_Answer"], how="left")
train.is_correct = train.is_correct.fillna(0)

# # 問題別の選択肢を抽出してカンマ区切りの文字列として追加
# question_choices = train.groupby("QuestionId")["Misconception"].apply(lambda x: sorted(x.unique())).reset_index()
# question_choices.columns = ["QuestionId", "choices_list"]
# question_choices["choices"] = question_choices["choices_list"].apply(lambda x: ", ".join(x))
# train = train.merge(question_choices[["QuestionId", "choices"]], on="QuestionId", how="left")

# %% [markdown]
# ## データの前処理

# %%
# tokenizerの読み込み
tokenizer = AutoTokenizer.from_pretrained(CFG.model_name)

# %%
# 学習データのtokenizer処理
def format_input(row):
    x = "Yes"
    if not row["is_correct"]:
        x = "No"
    return (
        f"Question: {row['QuestionText']}\n"
        # f"Choices: {row['choices']}\n"
        f"Answer: {row['MC_Answer']}\n"
        f"Correct: {x}\n"
        f"Student Explanation: {row['StudentExplanation']}"
    )

train["text"] = train.apply(format_input, axis=1)
print("LLMへのプロンプト例:")
print()
print(train.text.values[0])
# Out:
# LLMへのプロンプト例:
#
# Question: What fraction of the shape is not shaded? Give your answer in its simplest form. [Image: A triangle split into 9 equal smaller triangles. 6 of them are shaded.]
# Answer: \( \frac{1}{3} \)
# Correct: Yes
# Student Explanation: 0ne third is equal to tree nineth

# %%
lengths = [len(tokenizer.encode(t, truncation=False)) for t in train["text"]]

# トークン長の分布を可視化
plt.hist(lengths, bins=50)
plt.xlabel("token_length")
plt.ylabel("count")
plt.grid(True)
plt.show()

# max_lenを超えるサンプル数を確認
L = (np.array(lengths) > CFG.max_len).sum()
print(f"{CFG.max_len}トークンを超える訓練サンプルが{L}個あります")
np.sort(lengths)
# Out:
# 256トークンを超える訓練サンプルが0個あります
# array([ 31,  31,  31, ..., 178, 187, 231])

# %%
# 訓練データと検証データに分割
train_df = train[train.fold != 0]
val_df = train[train.fold == 0]

# Hugging Faceデータセットに変換
COLS = ["text", "label"]
train_ds = Dataset.from_pandas(train_df[COLS])
val_ds = Dataset.from_pandas(val_df[COLS])

# %%
# トークナイズ関数
def tokenize(batch):
    return tokenizer(batch["text"], padding="max_length", truncation=True, max_length=256)

train_ds = train_ds.map(tokenize, batched=True)
val_ds = val_ds.map(tokenize, batched=True)

# PyTorch用のフォーマットを設定
columns = ["input_ids", "attention_mask", "label"]
train_ds.set_format(type="torch", columns=columns)
val_ds.set_format(type="torch", columns=columns)
# Out:
# Map:   0%|          | 0/29356 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7340 [00:00<?, ? examples/s]

# %% [markdown]
# ## 学習設定

# %%
# wandbのログイン
wandb.login(key=userdata.get("WANDB_API_KEY"))
wandb.init(project=CFG.comp_name, name=CFG.exp_name)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tomokazu_rikioka (tomokazu_rikioka_) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.3s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp004/wandb/run-20250912_001900-o36tbunf</code>
# Syncing run <strong><a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/o36tbunf' target="_blank">ettin-encoder-1b_exp004</a></strong> to <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map</a>
#  View run at <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/o36tbunf' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/o36tbunf</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/o36tbunf?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# モデルの読み込み
model = AutoModelForSequenceClassification.from_pretrained(
    CFG.model_name,
    num_labels=n_classes,
    reference_compile=False,
)
# hdim = model.config.hidden_size
# model.score = torch.nn.Sequential(
#     torch.nn.Dropout(0.1),
#     torch.nn.Linear(hdim, hdim // 2),
#     torch.nn.Dropout(0.1),
#     torch.nn.GELU(),
#     torch.nn.Linear(hdim // 2, 2),
# ).to(CFG.device)
# Out:
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at jhu-clsp/ettin-encoder-1b and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 学習の設定
training_args = TrainingArguments(
    output_dir=CFG.output_dir_path,
    do_train=True,
    do_eval=True,
    eval_strategy="steps",
    save_strategy="steps",
    num_train_epochs=CFG.num_train_epochs,
    per_device_train_batch_size=CFG.per_device_train_batch_size,
    gradient_accumulation_steps=CFG.gradient_accumulation_steps,
    per_device_eval_batch_size=CFG.per_device_eval_batch_size,
    learning_rate=CFG.learning_rate,
    optim=CFG.optim_type,
    lr_scheduler_type=CFG.lr_scheduler_type,
    warmup_steps=CFG.warmup_steps,
    weight_decay=CFG.weight_decay,
    logging_dir=CFG.log_dir_path,
    logging_steps=50,
    save_steps=600,
    eval_steps=300,
    save_total_limit=1,
    metric_for_best_model="map@3",
    greater_is_better=True,
    load_best_model_at_end=True,
    report_to="wandb",
    bf16=True,
    fp16=False,  # KaggleはT4なのでFP16で推論
)

# %%
# カスタムメトリック
def compute_map3(eval_pred):
    logits, labels = eval_pred
    probs = torch.nn.functional.softmax(torch.tensor(logits), dim=-1).numpy()

    top3 = np.argsort(-probs, axis=1)[:, :3]  # トップ3の予測
    match = top3 == labels[:, None]

    # MAP@3を計算
    map3 = 0
    for i in range(len(labels)):
        if match[i, 0]:
            map3 += 1.0
        elif match[i, 1]:
            map3 += 1.0 / 2
        elif match[i, 2]:
            map3 += 1.0 / 3
    return {"map@3": map3 / len(labels)}

# %% [markdown]
# ## モデルの学習

# %%
# トレーナーの設定
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    processing_class=tokenizer,
    compute_metrics=compute_map3,
)
# hdim = model.config.hidden_size
# model.score = torch.nn.Sequential(
#     torch.nn.Dropout(0.1),
#     torch.nn.Linear(hdim, hdim // 2),
#     torch.nn.Dropout(0.1),
#     torch.nn.GELU(),
#     torch.nn.Linear(hdim // 2, 2),
# ).bfloat16().to(CFG.device)

# モデルの学習
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': None, 'bos_token_id': None}.
#     <div>
#
#       <progress value='9180' max='9180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9180/9180 1:32:16, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Map@3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>0.529300</td>
#       <td>0.558343</td>
#       <td>0.892984</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.502100</td>
#       <td>0.425583</td>
#       <td>0.920186</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.434100</td>
#       <td>0.440877</td>
#       <td>0.911717</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.335500</td>
#       <td>0.427234</td>
#       <td>0.923638</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.345500</td>
#       <td>0.374369</td>
#       <td>0.931789</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.390100</td>
#       <td>0.352258</td>
#       <td>0.931335</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.248000</td>
#       <td>0.404160</td>
#       <td>0.930518</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.249800</td>
#       <td>0.391061</td>
#       <td>0.932879</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.266200</td>
#       <td>0.373513</td>
#       <td>0.932334</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.143900</td>
#       <td>0.472773</td>
#       <td>0.933311</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.171000</td>
#       <td>0.413657</td>
#       <td>0.936944</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.181700</td>
#       <td>0.447312</td>
#       <td>0.936898</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.104600</td>
#       <td>0.562870</td>
#       <td>0.930858</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.102300</td>
#       <td>0.506400</td>
#       <td>0.936966</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.099600</td>
#       <td>0.567623</td>
#       <td>0.934196</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.057000</td>
#       <td>0.681651</td>
#       <td>0.937239</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.049500</td>
#       <td>0.763849</td>
#       <td>0.933243</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.057600</td>
#       <td>0.695045</td>
#       <td>0.935082</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.028300</td>
#       <td>0.904493</td>
#       <td>0.934832</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.026200</td>
#       <td>0.964102</td>
#       <td>0.933061</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.023600</td>
#       <td>0.928536</td>
#       <td>0.934310</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.009600</td>
#       <td>1.042428</td>
#       <td>0.935127</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.021300</td>
#       <td>1.065462</td>
#       <td>0.935309</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.032400</td>
#       <td>1.009277</td>
#       <td>0.936353</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.005800</td>
#       <td>1.131933</td>
#       <td>0.935945</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.007300</td>
#       <td>1.195941</td>
#       <td>0.935695</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.009900</td>
#       <td>1.224512</td>
#       <td>0.935218</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.007600</td>
#       <td>1.235479</td>
#       <td>0.934718</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.003500</td>
#       <td>1.247281</td>
#       <td>0.935195</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.005300</td>
#       <td>1.253151</td>
#       <td>0.934900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9180, training_loss=0.15338615996921373, metrics={'train_runtime': 5536.3045, 'train_samples_per_second': 53.025, 'train_steps_per_second': 1.658, 'total_flos': 4.243590631456973e+17, 'train_loss': 0.15338615996921373, 'epoch': 10.0})

# %% [markdown]
# ## モデルの保存

# %%
trainer.save_model(f"{CFG.output_dir_path}/model")
tokenizer.save_pretrained(f"{CFG.output_dir_path}/tokenizer")
# Out:
# ('output//tokenizer/tokenizer_config.json',
#  'output//tokenizer/special_tokens_map.json',
#  'output//tokenizer/tokenizer.json')

# %%
# WandBのセッションを終了
with wandb.init():
    wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>▃▂▂▂▁▁▁▁▁▂▁▂▃▂▃▄▄▄▅▆▅▆▇▆▇█████</td></tr><tr><td>eval/map@3</td><td>▁▅▄▆▇▇▇▇▇▇██▇███▇██▇██████████</td></tr><tr><td>eval/runtime</td><td>▁▁▃▃█▄▅▇▃▃▃▃▃▃▂▄▃▃▄▃▃▃▃▃▄▃▅▅▃▃</td></tr><tr><td>eval/samples_per_second</td><td>██▆▆▁▅▄▂▆▆▆▆▆▆▇▅▆▆▅▆▆▆▆▆▅▆▄▄▆▆</td></tr><tr><td>eval/steps_per_second</td><td>██▆▆▁▅▄▂▆▆▆▆▆▆▇▅▆▆▆▆▆▆▆▆▅▆▄▄▆▆</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>train/grad_norm</td><td>█▆▄▄▅▃▃▄▃▄▃▄▃▄▆▃▃▁▁▂▂▂▁▁▁▁▂▁▁▃▁▁▁▁▂▂▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>█████▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▇▇▆▆▆▅▅▅▃▄▄▄▃▃▃▃▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>1.25315</td></tr><tr><td>eval/map@3</td><td>0.9349</td></tr><tr><td>eval/runtime</td><td>27.818</td></tr><tr><td>eval/samples_per_second</td><td>263.858</td></tr><tr><td>eval/steps_per_second</td><td>4.134</td></tr><tr><td>total_flos</td><td>4.243590631456973e+17</td></tr><tr><td>train/epoch</td><td>10</td></tr><tr><td>train/global_step</td><td>9180</td></tr><tr><td>train/grad_norm</td><td>0.10548</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ettin-encoder-1b_exp004</strong> at: <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/o36tbunf' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/o36tbunf</a><br> View project at: <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250912_001900-o36tbunf/logs</code>
# creating run (0.3s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp004/wandb/run-20250912_015139-3kpq4hhb</code>
# Syncing run <strong><a href='https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/3kpq4hhb' target="_blank">cerulean-voice-8</a></strong> to <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized</a>
#  View run at <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/3kpq4hhb' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/3kpq4hhb</a>
#  View run <strong style="color:#cdcd00">cerulean-voice-8</strong> at: <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/3kpq4hhb' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/3kpq4hhb</a><br> View project at: <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250912_015139-3kpq4hhb/logs</code>

# %%
# キャッシュ削除
del model, tokenizer, trainer
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # 結果分析

# %%
# 学習済みモデルの読み込み
model_path = f"{CFG.output_dir_path}/model"
tokenizer_path = f"{CFG.output_dir_path}/tokenizer"

inference_model = AutoModelForSequenceClassification.from_pretrained(
    model_path,
    num_labels=n_classes,
    reference_compile=False,
)
# hdim = inference_model.config.hidden_size
# inference_model.score = torch.nn.Sequential(
#     torch.nn.Dropout(0.1),
#     torch.nn.Linear(hdim, hdim // 2),
#     torch.nn.Dropout(0.1),
#     torch.nn.GELU(),
#     torch.nn.Linear(hdim // 2, 2),
# ).bfloat16().to(CFG.device)
inference_tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

# 推論用のインスタンスを作成
inference_trainer = Trainer(
    model=inference_model,
    processing_class=inference_tokenizer
)

# 検証データの推論実行
inference_model.eval()
start_time = time.time()

val_predictions = inference_trainer.predict(val_ds)
logits = val_predictions.predictions
val_labels = val_predictions.label_ids

# 推論時間を計算
inference_time = time.time() - start_time
print(f"推論時間: {inference_time:.2f}秒")
print(f"サンプル数: {len(val_labels)}個")
print(f"1サンプルあたりの推論時間: {inference_time/len(val_labels)*1000:.2f}ms")

# 確率値に変換
val_probs = torch.nn.functional.softmax(torch.tensor(logits), dim=-1).numpy()

# Top-1精度の計算
val_pred_labels = np.argmax(logits, axis=1)
accuracy = (val_pred_labels == val_labels).mean()
print(f"\nTop-1精度: {accuracy:.4f}")

# MAP@3スコアの計算
map3_score = compute_map3((logits, val_labels))["map@3"]
print(f"MAP@3スコア: {map3_score:.4f}")
# Out:
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp004/wandb/run-20250912_015235-0zmbtmcn</code>
# Syncing run <strong><a href='https://wandb.ai/tomokazu_rikioka_/huggingface/runs/0zmbtmcn' target="_blank">daily-galaxy-8</a></strong> to <a href='https://wandb.ai/tomokazu_rikioka_/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomokazu_rikioka_/huggingface' target="_blank">https://wandb.ai/tomokazu_rikioka_/huggingface</a>
#  View run at <a href='https://wandb.ai/tomokazu_rikioka_/huggingface/runs/0zmbtmcn' target="_blank">https://wandb.ai/tomokazu_rikioka_/huggingface/runs/0zmbtmcn</a>
# 推論時間: 44.39秒
# サンプル数: 7340個
# 1サンプルあたりの推論時間: 6.05ms
#
# Top-1精度: 0.8838
# MAP@3スコア: 0.9372

# %% [markdown]
# ## 項目別の結果分析

# %%
# Top-3予測の取得
top3_indices = np.argsort(-val_probs, axis=1)[:, :3]
top3_probs = np.take_along_axis(val_probs, top3_indices, axis=1)

# Top-1予測の取得
max_probs = val_probs.max(axis=1)

# %%
# 検証データに必要な情報を追加
val_df_analysis = val_df.copy()
val_df_analysis["pred_label"] = val_pred_labels
val_df_analysis["actual_label"] = val_labels
val_df_analysis["confidence"] = max_probs
val_df_analysis["is_correct"] = (val_pred_labels == val_labels)

# Top-3予測の情報を追加
for i in range(3):
    val_df_analysis[f"top{i+1}_label"] = top3_indices[:, i]
    val_df_analysis[f"top{i+1}_prob"] = top3_probs[:, i]
    val_df_analysis[f"top{i+1}_name"] = [le.inverse_transform([x])[0] for x in top3_indices[:, i]]

# Top-3に正解が含まれているか
val_df_analysis["is_in_top3"] = [label in top3_indices[i] for i, label in enumerate(val_labels)]

# MAP@3スコアを各サンプルごとに計算
def calculate_map3_per_sample(row):
    if row["actual_label"] == row["top1_label"]:
        return 1.0
    elif row["actual_label"] == row["top2_label"]:
        return 1.0 / 2
    elif row["actual_label"] == row["top3_label"]:
        return 1.0 / 3
    else:
        return 0.0

val_df_analysis["map3_score"] = val_df_analysis.apply(calculate_map3_per_sample, axis=1)

# CategoryとMisconceptionを分離
val_df_analysis["actual_category"] = val_df_analysis["target"].apply(lambda x: x.split(":")[0])
val_df_analysis["actual_misconception"] = val_df_analysis["target"].apply(lambda x: x.split(":")[1])
val_df_analysis["pred_category"] = val_df_analysis["top1_name"].apply(lambda x: x.split(":")[0])
val_df_analysis["pred_misconception"] = val_df_analysis["top1_name"].apply(lambda x: x.split(":")[1])

# %% [markdown]
# ### Questionごとの予測確率分布

# %%
question_stats = val_df_analysis.groupby("QuestionId").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "QuestionText": "first",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "label": "Sample_Count"
}).sort_values("MAP@3", ascending=False)

# 結果の表示
question_stats = question_stats.reset_index()
question_stats
# Out:
#     QuestionId     MAP@3  Top1_Accuracy  Top3_Accuracy  Avg_Confidence  \
# 0        31777  0.969454       0.939502       1.000000        0.989697
# 1        32829  0.960170       0.925754       0.995360        0.988983
# 2        31772  0.952846       0.910494       0.996914        0.964367
# 3        33471  0.950917       0.915858       0.990291        0.989812
# 4        32833  0.943371       0.888889       0.998390        0.973002
# 5        89443  0.941626       0.896890       0.990180        0.975723
# 6       104665  0.938272       0.888889       0.992593        0.974646
# 7        76870  0.935302       0.873418       1.000000        0.986851
# 8        33472  0.932440       0.869643       0.996429        0.969607
# 9       109465  0.930159       0.861905       1.000000        0.972374
# 10       31774  0.929106       0.866774       0.996790        0.974521
# 11       91695  0.928480       0.873563       0.986590        0.974404
# 12       31778  0.920101       0.858516       0.989011        0.972406
# 13       32835  0.905222       0.830472       0.982833        0.965950
# 14       33474  0.902266       0.818697       0.985836        0.976042
#
#                                          QuestionText  Sample_Count
# 0   A box contains \( 120 \) counters. The counter...           562
# 1         \( 2 y=24 \) What is the value of \( y \) ?           431
# 2   What fraction of the shape is not shaded? Give...           972
# 3   A bag contains \( 24 \) yellow and green balls...           309
# 4                Calculate \( \frac{2}{3} \times 5 \)           621
# 5   What number belongs in the box?\n\(\n(-8)-(-5)...           611
# 6   It takes \( 3 \) people a total of \( 192 \) h...           135
# 7   This is part of a regular polygon. How many si...           237
# 8                      \( \frac{1}{3}+\frac{2}{5}= \)           560
# 9   The probability of an event occurring is \( 0....           210
# 10                 Calculate \( \frac{1}{2} \div 6 \)           623
# 11  Dots have been arranged in these patterns: [Im...           522
# 12  \( \frac{A}{10}=\frac{9}{15} \) What is the va...           728
# 13                      Which number is the greatest?           466
# 14  Sally has \( \frac{2}{3} \) of a whole cake in...           353

# %% [markdown]
# ### Categoryごとの予測確率分布

# %%
category_stats = val_df_analysis.groupby("actual_category").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "label": "Sample_Count"
}).sort_values("MAP@3", ascending=False)

# 結果の表示
category_stats = category_stats.reset_index()
category_stats
# Out:
#        actual_category     MAP@3  Top1_Accuracy  Top3_Accuracy  \
# 0         True_Correct  0.973302       0.949307       0.997634
# 1  False_Misconception  0.954129       0.924459       0.987850
# 2        False_Neither  0.905581       0.816514       0.996942
# 3         True_Neither  0.870810       0.744782       1.000000
# 4        False_Correct  0.794574       0.697674       0.906977
# 5   True_Misconception  0.682731       0.542169       0.879518
#
#    Avg_Confidence  Sample_Count
# 0        0.986623          2959
# 1        0.981418          1893
# 2        0.957095          1308
# 3        0.957686          1054
# 4        0.924068            43
# 5        0.949573            83

# %% [markdown]
# ### Misconceptionごとの予測確率分布

# %%
misconception_stats = val_df_analysis.groupby("actual_misconception").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "label": "Sample_Count"
}).sort_values("MAP@3", ascending=False)

# 結果の表示
misconception_stats = misconception_stats.reset_index()
display(misconception_stats.head())
display(misconception_stats.tail())
# Out:
#   actual_misconception  MAP@3  Top1_Accuracy  Top3_Accuracy  Avg_Confidence  \
# 0       Wrong_Fraction    1.0            1.0            1.0        0.996528
# 1             Interior    1.0            1.0            1.0        0.995636
# 2    Inverse_operation    1.0            1.0            1.0        0.949041
# 3       Ignores_zeroes    1.0            1.0            1.0        0.990503
# 4      Wrong_Operation    1.0            1.0            1.0        0.945295
#
#    Sample_Count
# 0            55
# 1            10
# 2             4
# 3             4
# 4             1
#                       actual_misconception     MAP@3  Top1_Accuracy  \
# 31                               Base_rate  0.750000       0.666667
# 32                               Firstterm  0.651515       0.545455
# 33                        Longer_is_bigger  0.600000       0.600000
# 34  Incorrect_equivalent_fraction_addition  0.500000       0.500000
# 35                       Shorter_is_bigger  0.208333       0.000000
#
#     Top3_Accuracy  Avg_Confidence  Sample_Count
# 31       0.833333        0.920996             6
# 32       0.772727        0.877752            22
# 33       0.600000        0.810538             5
# 34       0.500000        0.989874             2
# 35       0.500000        0.989033             4

# %% [markdown]
# ### ラベル（Category:Misconception）ごとの予測確率分布

# %%
label_level_stats = val_df_analysis.groupby("target").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "top1_prob": "mean",
    "top2_prob": "mean",
    "top3_prob": "mean",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "top1_prob": "Avg_Top1_Prob",
    "top2_prob": "Avg_Top2_Prob",
    "top3_prob": "Avg_Top3_Prob",
    "label": "Sample_Count"
}).sort_values('MAP@3', ascending=False)

# 結果を表示
label_level_stats = label_level_stats.reset_index()
display(label_level_stats.head())
display(label_level_stats.tail())
# Out:
#                                               target  MAP@3  Top1_Accuracy  \
# 0              False_Misconception:Inverse_operation    1.0            1.0
# 1                       False_Misconception:Interior    1.0            1.0
# 2  False_Misconception:Incorrect_equivalent_fract...    1.0            1.0
# 3                 False_Misconception:Ignores_zeroes    1.0            1.0
# 4                 False_Misconception:Wrong_Fraction    1.0            1.0
#
#    Top3_Accuracy  Avg_Confidence  Avg_Top1_Prob  Avg_Top2_Prob  Avg_Top3_Prob  \
# 0            1.0        0.949041       0.949041       0.034665       0.015515
# 1            1.0        0.995636       0.995636       0.004300       0.000057
# 2            1.0        0.993525       0.993525       0.003473       0.000775
# 3            1.0        0.990503       0.990503       0.007986       0.001481
# 4            1.0        0.996528       0.996528       0.002767       0.000574
#
#    Sample_Count
# 0             4
# 1            10
# 2             1
# 3             4
# 4            55
#                                                target  MAP@3  Top1_Accuracy  \
# 55                   True_Misconception:Adding_across    0.0            0.0
# 56                       True_Misconception:Base_rate    0.0            0.0
# 57  True_Misconception:Incorrect_equivalent_fracti...    0.0            0.0
# 58                     True_Misconception:Subtraction    0.0            0.0
# 59            True_Misconception:Whole_numbers_larger    0.0            0.0
#
#     Top3_Accuracy  Avg_Confidence  Avg_Top1_Prob  Avg_Top2_Prob  \
# 55            0.0        0.999867       0.999867       0.000109
# 56            0.0        0.646491       0.646491       0.346042
# 57            0.0        0.986224       0.986224       0.003557
# 58            0.0        0.931910       0.931910       0.052575
# 59            0.0        0.998244       0.998244       0.001501
#
#     Avg_Top3_Prob  Sample_Count
# 55       0.000013             1
# 56       0.006747             1
# 57       0.002027             1
# 58       0.008319             1
# 59       0.000036             1

# %%
# CSVで保存
question_stats.to_csv(f"{CFG.output_dir_path}/question_statistics.csv")
category_stats.to_csv(f"{CFG.output_dir_path}/category_statistics.csv")
misconception_stats.to_csv(f"{CFG.output_dir_path}/misconception_statistics.csv")
label_level_stats.to_csv(f"{CFG.output_dir_path}/label_level_statistics.csv")

# %%
# 検証データの全レコードに予測結果を付与したデータフレームを保存
val_df_with_predictions = val_df_analysis[[
    "row_id", "QuestionId", "QuestionText", "MC_Answer", "StudentExplanation",
    "Category", "Misconception", "target", "label", "actual_label",
    "pred_label", "confidence", "is_correct", "is_in_top3", "map3_score",
    "top1_label", "top1_prob", "top1_name",
    "top2_label", "top2_prob", "top2_name",
    "top3_label", "top3_prob", "top3_name",
    "actual_category", "actual_misconception",
    "pred_category", "pred_misconception"
]]

val_df_with_predictions.to_csv(f"{CFG.output_dir_path}/val_predictions_full.csv", index=False)

# %% [markdown]
# ## 誤分類サンプルの分析

# %% [markdown]
# ### Top-1で誤分類したサンプル

# %%
# 誤分類サンプルの特定
misclassified_mask = (val_pred_labels != val_labels)
misclassified_indices = np.where(misclassified_mask)[0]

print(f"誤分類サンプル数: {len(misclassified_indices)} / {len(val_labels)} ({len(misclassified_indices)/len(val_labels)*100:.1f}%)")

# 確信度の低いサンプルトップ10を表示
low_confidence_indices = np.argsort(max_probs)[:10]
print(f"\n=== 確信度の低いサンプル（上位10件）===")

for i, idx in enumerate(low_confidence_indices):
    actual_label = val_labels[idx]
    pred_label = val_pred_labels[idx]
    confidence = max_probs[idx]
    is_correct = "正解" if actual_label == pred_label else "誤り"

    actual_name = le.inverse_transform([actual_label])[0]
    pred_name = le.inverse_transform([pred_label])[0]

    print(f"#{i+1:2d} 確信度={confidence:.3f} ({is_correct})")
    print(f"    実際: {actual_name}")
    print(f"    予測: {pred_name}")
    print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
    print(f"    Top-3確率: {top3_probs[idx]}")
    print()

# 誤分類の中で確信度の高いサンプルを表示（モデルが自信を持って間違えたケース）
if len(misclassified_indices) > 0:
    misclassified_confidences = max_probs[misclassified_indices]
    high_confidence_wrong_indices = misclassified_indices[np.argsort(-misclassified_confidences)[:10]]

    print(f"=== 高確信度で誤分類したサンプル（上位10件）===")
    for i, idx in enumerate(high_confidence_wrong_indices):
        actual_label = val_labels[idx]
        pred_label = val_pred_labels[idx]
        confidence = max_probs[idx]

        actual_name = le.inverse_transform([actual_label])[0]
        pred_name = le.inverse_transform([pred_label])[0]

        print(f"#{i+1} 確信度={confidence:.3f}")
        print(f"    実際: {actual_name}")
        print(f"    予測: {pred_name}")
        print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
        print(f"    Top-3確率: {top3_probs[idx]}")
        print()
# Out:
# 誤分類サンプル数: 853 / 7340 (11.6%)
#
# === 確信度の低いサンプル（上位10件）===
# # 1 確信度=0.347 (誤り)
#     実際: False_Neither:NA
#     予測: False_Misconception:Ignores_zeroes
#     Top-3予測: ['False_Misconception:Ignores_zeroes', 'False_Neither:NA', 'False_Correct:NA']
#     Top-3確率: [0.34681737 0.34681737 0.30606526]
#
# # 2 確信度=0.410 (正解)
#     実際: False_Neither:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Correct:NA', 'False_Misconception:Whole_numbers_larger']
#     Top-3確率: [0.4103025  0.36209068 0.20631304]
#
# # 3 確信度=0.433 (正解)
#     実際: False_Misconception:WNB
#     予測: False_Misconception:WNB
#     Top-3予測: ['False_Misconception:WNB', 'False_Neither:NA', 'False_Misconception:Irrelevant']
#     Top-3確率: [0.43250698 0.29725742 0.26232874]
#
# # 4 確信度=0.466 (正解)
#     実際: False_Neither:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Incomplete', 'False_Misconception:Wrong_Fraction']
#     Top-3確率: [0.46575835 0.36273298 0.16096179]
#
# # 5 確信度=0.472 (誤り)
#     実際: True_Neither:NA
#     予測: True_Misconception:Wrong_term
#     Top-3予測: ['True_Misconception:Wrong_term', 'True_Correct:NA', 'True_Neither:NA']
#     Top-3確率: [0.4717664 0.2525184 0.2525184]
#
# # 6 確信度=0.477 (誤り)
#     実際: False_Correct:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'False_Correct:NA', 'False_Neither:NA']
#     Top-3確率: [0.47749546 0.44856548 0.0732263 ]
#
# # 7 確信度=0.495 (誤り)
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [0.4949364  0.4949364  0.00441797]
#
# # 8 確信度=0.496 (誤り)
#     実際: False_Neither:NA
#     予測: False_Misconception:Tacking
#     Top-3予測: ['False_Misconception:Tacking', 'False_Neither:NA', 'False_Misconception:Positive']
#     Top-3確率: [0.49575394 0.49575394 0.00664311]
#
# # 9 確信度=0.496 (誤り)
#     実際: False_Neither:NA
#     予測: False_Misconception:Adding_across
#     Top-3予測: ['False_Misconception:Adding_across', 'False_Neither:NA', 'False_Misconception:Denominator-only_change']
#     Top-3確率: [0.49606776 0.49606776 0.002904  ]
#
# #10 確信度=0.496 (誤り)
#     実際: False_Neither:NA
#     予測: False_Misconception:Whole_numbers_larger
#     Top-3予測: ['False_Misconception:Whole_numbers_larger', 'False_Neither:NA', 'True_Neither:NA']
#     Top-3確率: [0.49638215 0.49638215 0.00624853]
#
# === 高確信度で誤分類したサンプル（上位10件）===
# #1 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Positive']
#     Top-3確率: [1.0000000e+00 3.0288433e-08 1.1744099e-09]
#
# #2 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Inversion']
#     Top-3確率: [1.0000000e+00 5.3157851e-08 1.1382771e-09]
#
# #3 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'False_Correct:NA']
#     Top-3確率: [1.0000000e+00 3.0288433e-08 3.3647407e-10]
#
# #4 確信度=1.000
#     実際: True_Correct:NA
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Correct:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [1.0000000e+00 9.2374499e-09 1.3750926e-12]
#
# #5 確信度=1.000
#     実際: False_Neither:NA
#     予測: False_Misconception:Whole_numbers_larger
#     Top-3予測: ['False_Misconception:Whole_numbers_larger', 'False_Neither:NA', 'True_Misconception:Longer_is_bigger']
#     Top-3確率: [1.0000000e+00 8.1520204e-09 2.8780153e-10]
#
# #6 確信度=1.000
#     実際: False_Neither:NA
#     予測: False_Misconception:Whole_numbers_larger
#     Top-3予測: ['False_Misconception:Whole_numbers_larger', 'True_Misconception:Shorter_is_bigger', 'False_Neither:NA']
#     Top-3確率: [1.000000e+00 5.905304e-10 4.058652e-10]
#
# #7 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [1.0000000e+00 4.6448814e-09 8.5921664e-10]
#
# #8 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [1.000000e+00 6.224145e-11 3.403387e-12]
#
# #9 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [1.0000000e+00 3.0288433e-08 2.4097326e-09]
#
# #10 確信度=1.000
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [1.0000000e+00 3.4321289e-08 2.2637343e-09]

# %% [markdown]
# ### Top-3で誤分類したサンプル

# %%
# 誤分類サンプルの特定
misclassified_mask = [val_labels[i] not in top3_indices[i] for i in range(len(val_labels))]
misclassified_indices = np.where(misclassified_mask)[0]

print(f"誤分類サンプル数: {len(misclassified_indices)} / {len(val_labels)} "
      f"({len(misclassified_indices)/len(val_labels)*100:.1f}%)")

# 確信度の低いサンプルトップ10を表示
low_confidence_indices = np.argsort(max_probs)[:10]
print(f"\n=== 確信度の低いサンプル（上位10件）===")

for i, idx in enumerate(low_confidence_indices):
    actual_label = val_labels[idx]
    pred_label = val_pred_labels[idx]
    confidence = max_probs[idx]
    is_correct = "正解" if actual_label in top3_indices[idx] else "誤り"

    actual_name = le.inverse_transform([actual_label])[0]
    pred_name = le.inverse_transform([pred_label])[0]

    print(f"#{i+1:2d} 確信度={confidence:.3f} ({is_correct})")
    print(f"    実際: {actual_name}")
    print(f"    予測: {pred_name}")
    print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
    print(f"    Top-3確率: {top3_probs[idx]}")
    print()

# 誤分類の中で確信度の高いサンプルを表示（モデルが自信を持って間違えたケース）
if len(misclassified_indices) > 0:
    misclassified_confidences = max_probs[misclassified_indices]
    high_confidence_wrong_indices = misclassified_indices[np.argsort(-misclassified_confidences)[:10]]

    print(f"=== 高確信度で誤分類したサンプル（上位10件）===")
    for i, idx in enumerate(high_confidence_wrong_indices):
        actual_label = val_labels[idx]
        pred_label = val_pred_labels[idx]
        confidence = max_probs[idx]

        actual_name = le.inverse_transform([actual_label])[0]
        pred_name = le.inverse_transform([pred_label])[0]

        print(f"#{i+1} 確信度={confidence:.3f}")
        print(f"    実際: {actual_name}")
        print(f"    予測: {pred_name}")
        print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
        print(f"    Top-3確率: {top3_probs[idx]}")
        print()
# Out:
# 誤分類サンプル数: 48 / 7340 (0.7%)
#
# === 確信度の低いサンプル（上位10件）===
# # 1 確信度=0.347 (正解)
#     実際: False_Neither:NA
#     予測: False_Misconception:Ignores_zeroes
#     Top-3予測: ['False_Misconception:Ignores_zeroes', 'False_Neither:NA', 'False_Correct:NA']
#     Top-3確率: [0.34681737 0.34681737 0.30606526]
#
# # 2 確信度=0.410 (正解)
#     実際: False_Neither:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Correct:NA', 'False_Misconception:Whole_numbers_larger']
#     Top-3確率: [0.4103025  0.36209068 0.20631304]
#
# # 3 確信度=0.433 (正解)
#     実際: False_Misconception:WNB
#     予測: False_Misconception:WNB
#     Top-3予測: ['False_Misconception:WNB', 'False_Neither:NA', 'False_Misconception:Irrelevant']
#     Top-3確率: [0.43250698 0.29725742 0.26232874]
#
# # 4 確信度=0.466 (正解)
#     実際: False_Neither:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Incomplete', 'False_Misconception:Wrong_Fraction']
#     Top-3確率: [0.46575835 0.36273298 0.16096179]
#
# # 5 確信度=0.472 (正解)
#     実際: True_Neither:NA
#     予測: True_Misconception:Wrong_term
#     Top-3予測: ['True_Misconception:Wrong_term', 'True_Correct:NA', 'True_Neither:NA']
#     Top-3確率: [0.4717664 0.2525184 0.2525184]
#
# # 6 確信度=0.477 (正解)
#     実際: False_Correct:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'False_Correct:NA', 'False_Neither:NA']
#     Top-3確率: [0.47749546 0.44856548 0.0732263 ]
#
# # 7 確信度=0.495 (正解)
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [0.4949364  0.4949364  0.00441797]
#
# # 8 確信度=0.496 (正解)
#     実際: False_Neither:NA
#     予測: False_Misconception:Tacking
#     Top-3予測: ['False_Misconception:Tacking', 'False_Neither:NA', 'False_Misconception:Positive']
#     Top-3確率: [0.49575394 0.49575394 0.00664311]
#
# # 9 確信度=0.496 (正解)
#     実際: False_Neither:NA
#     予測: False_Misconception:Adding_across
#     Top-3予測: ['False_Misconception:Adding_across', 'False_Neither:NA', 'False_Misconception:Denominator-only_change']
#     Top-3確率: [0.49606776 0.49606776 0.002904  ]
#
# #10 確信度=0.496 (正解)
#     実際: False_Neither:NA
#     予測: False_Misconception:Whole_numbers_larger
#     Top-3予測: ['False_Misconception:Whole_numbers_larger', 'False_Neither:NA', 'True_Neither:NA']
#     Top-3確率: [0.49638215 0.49638215 0.00624853]
#
# === 高確信度で誤分類したサンプル（上位10件）===
# #1 確信度=1.000
#     実際: False_Correct:NA
#     予測: False_Misconception:Wrong_fraction
#     Top-3予測: ['False_Misconception:Wrong_fraction', 'False_Neither:NA', 'True_Misconception:Wrong_fraction']
#     Top-3確率: [9.9999976e-01 2.8736858e-07 4.1399364e-08]
#
# #2 確信度=1.000
#     実際: False_Misconception:Additive
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'True_Neither:NA', 'False_Misconception:Irrelevant']
#     Top-3確率: [9.9999833e-01 7.8114766e-07 2.9649021e-07]
#
# #3 確信度=1.000
#     実際: False_Misconception:Tacking
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'True_Neither:NA', 'False_Misconception:Positive']
#     Top-3確率: [9.9999547e-01 3.7266364e-06 6.4759229e-07]
#
# #4 確信度=1.000
#     実際: False_Misconception:Longer_is_bigger
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'True_Neither:NA', 'False_Misconception:Scale']
#     Top-3確率: [9.9999344e-01 6.5404374e-06 4.4575282e-10]
#
# #5 確信度=1.000
#     実際: False_Misconception:Irrelevant
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'True_Neither:NA', 'False_Misconception:Scale']
#     Top-3確率: [9.9999249e-01 7.4112795e-06 5.1521969e-08]
#
# #6 確信度=1.000
#     実際: False_Misconception:Positive
#     予測: False_Misconception:Tacking
#     Top-3予測: ['False_Misconception:Tacking', 'False_Neither:NA', 'True_Misconception:Tacking']
#     Top-3確率: [9.9995363e-01 4.0063438e-05 4.0927380e-06]
#
# #7 確信度=1.000
#     実際: False_Misconception:Mult
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Correct:NA', 'False_Misconception:Incomplete']
#     Top-3確率: [9.999106e-01 7.967224e-05 2.902061e-06]
#
# #8 確信度=1.000
#     実際: True_Misconception:Tacking
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Correct:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [9.9990392e-01 9.0279864e-05 1.9945421e-06]
#
# #9 確信度=1.000
#     実際: True_Misconception:Shorter_is_bigger
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [9.9989104e-01 1.0889690e-04 6.2234669e-11]
#
# #10 確信度=1.000
#     実際: True_Misconception:Adding_across
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Denominator-only_change']
#     Top-3確率: [9.99867201e-01 1.08894303e-04 1.30055705e-05]

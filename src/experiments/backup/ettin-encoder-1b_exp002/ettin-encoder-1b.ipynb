# %%
# Google Colabでの設定
google_colab = True

if google_colab:
    from google.colab import drive
    from google.colab import userdata

    drive.mount("/content/drive")

    # ディレクトリ移動
    # %cd /content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp002
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp002

# %%
import os
import gc
import time
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

import torch
import wandb
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer

# %%
class CFG:
    """実験設定管理クラス"""

    # ============== 実験情報 =============
    comp_name = "kaggle_map"
    exp_name = "ettin-encoder-1b_exp002"
    model_name = "jhu-clsp/ettin-encoder-1b"

    # ============== ファイルパス設定 =============
    comp_dir_path = "../../kaggle/input/"
    comp_dataset_path = f"{comp_dir_path}/map-charting-student-math-misunderstandings/"
    output_dir_path = "output/"
    log_dir_path = "logs/"

    # ============== モデル設定 =============
    max_len = 256

    num_train_epochs = 3
    per_device_train_batch_size = 32
    gradient_accumulation_steps = 1
    per_device_eval_batch_size = 64
    optim_type = "adamw_torch"
    learning_rate = 5e-5
    lr_scheduler_type = "cosine"
    warmup_steps = 50
    weight_decay = 0.01

    # ============== その他設定 =============
    seed = 42
    device = torch.device("cuda")

# %%
# 乱数固定
def set_seed(seed=None, cudnn_deterministic=True):
    if seed is None:
        seed = 42

    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = cudnn_deterministic
    torch.backends.cudnn.benchmark = False

def make_dirs(cfg):
    for dir in [cfg.output_dir_path, cfg.log_dir_path]:
        os.makedirs(dir, exist_ok=True)

def cfg_init(cfg):
    set_seed(cfg.seed)
    make_dirs(cfg)

# %% [markdown]
# # LLMの学習

# %% [markdown]
# ## データの読み込み

# %%
def add_folds_by_qid_cat_misc(df, n_splits=5, random_state=42, fallback="pair"):
    s_qid  = df["QuestionId"].astype(str).fillna("NA")
    s_cat  = df["Category"].astype(str).fillna("NA")
    s_misc = df["Misconception"].astype(str).fillna("NA")

    y_triple = s_qid + "|" + s_cat + "|" + s_misc
    y_pair   = s_cat + "|" + s_misc

    cnt = y_triple.value_counts()
    if (cnt < n_splits).any():
        if fallback == "pair":
            rare = y_triple.map(cnt) < n_splits
            y = np.where(rare, y_pair, y_triple)
        elif fallback == "category":
            rare = y_triple.map(cnt) < n_splits
            y = np.where(rare, s_cat, y_triple)
        elif fallback == "none":
            y = y_triple
        else:
            raise ValueError("fallback は 'pair' / 'category' / 'none' のいずれかにしてください。")
    else:
        y = y_triple

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    folds = np.full(len(df), -1, dtype=int)
    for fold, (_, val_idx) in enumerate(skf.split(np.zeros(len(df)), y)):
        folds[val_idx] = fold

    out = df.copy()
    out["fold"] = folds
    return out

# %%
# データ読み込み
train = pd.read_csv(f"{CFG.comp_dataset_path}/train.csv")
train = add_folds_by_qid_cat_misc(train, n_splits=5, random_state=42, fallback="pair")

train.Misconception = train.Misconception.fillna("NA")
train["target"] = train.Category + ":" + train.Misconception

# ラベルエンコード
le = LabelEncoder()
train["label"] = le.fit_transform(train["target"])

n_classes = len(le.classes_)
print(f"訓練データの形状: {train.shape} - {n_classes}個のターゲットクラス")
train.head(3)
# Out:
# 訓練データの形状: (36696, 10) - 65個のターゲットクラス
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
#    row_id  QuestionId                                       QuestionText  \
# 0       0       31772  What fraction of the shape is not shaded? Give...
# 1       1       31772  What fraction of the shape is not shaded? Give...
# 2       2       31772  What fraction of the shape is not shaded? Give...
#
#            MC_Answer                                 StudentExplanation  \
# 0  \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1  \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2  \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
#
#        Category Misconception  fold           target  label
# 0  True_Correct            NA     1  True_Correct:NA     37
# 1  True_Correct            NA     4  True_Correct:NA     37
# 2  True_Neither            NA     2  True_Neither:NA     64

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
# 正解ラベルの作成
idx = train.apply(lambda row: row.Category.split("_")[0], axis=1) == "True"
correct = train.loc[idx].copy()
correct["c"] = correct.groupby(["QuestionId", "MC_Answer"]).MC_Answer.transform("count")
correct = correct.sort_values("c", ascending=False)
correct = correct.drop_duplicates(["QuestionId"])
correct = correct[["QuestionId", "MC_Answer"]]
correct["is_correct"] = 1

# 正解ラベルを訓練データにマージ
train = train.merge(correct, on=["QuestionId", "MC_Answer"], how="left")
train.is_correct = train.is_correct.fillna(0)

# %% [markdown]
# ## データの前処理

# %%
# tokenizerの読み込み
tokenizer = AutoTokenizer.from_pretrained(CFG.model_name)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]

# %%
# 学習データのtokenizer処理
def format_input(row):
    x = "Yes"
    if not row["is_correct"]:
        x = "No"
    return (
        f"Question: {row['QuestionText']}\n"
        f"Answer: {row['MC_Answer']}\n"
        f"Correct: {x}\n"
        f"Student Explanation: {row['StudentExplanation']}"
    )

train["text"] = train.apply(format_input, axis=1)
print("LLMへのプロンプト例:")
print()
print(train.text.values[0])
# Out:
# LLMへのプロンプト例:
#
# Question: What fraction of the shape is not shaded? Give your answer in its simplest form. [Image: A triangle split into 9 equal smaller triangles. 6 of them are shaded.]
# Answer: \( \frac{1}{3} \)
# Correct: Yes
# Student Explanation: 0ne third is equal to tree nineth

# %%
lengths = [len(tokenizer.encode(t, truncation=False)) for t in train["text"]]

# トークン長の分布を可視化
plt.hist(lengths, bins=50)
plt.xlabel("token_length")
plt.ylabel("count")
plt.grid(True)
plt.show()

# max_lenを超えるサンプル数を確認
L = (np.array(lengths) > CFG.max_len).sum()
print(f"{CFG.max_len}トークンを超える訓練サンプルが{L}個あります")
np.sort(lengths)
# Out:
# 256トークンを超える訓練サンプルが0個あります
# array([ 31,  31,  31, ..., 178, 187, 231])

# %%
# 訓練データと検証データに分割
train_df = train[train.fold != 0]
val_df = train[train.fold == 0]

# Hugging Faceデータセットに変換
COLS = ["text", "label"]
train_ds = Dataset.from_pandas(train_df[COLS])
val_ds = Dataset.from_pandas(val_df[COLS])

# %%
# トークナイズ関数
def tokenize(batch):
    return tokenizer(batch["text"], padding="max_length", truncation=True, max_length=256)

train_ds = train_ds.map(tokenize, batched=True)
val_ds = val_ds.map(tokenize, batched=True)

# PyTorch用のフォーマットを設定
columns = ["input_ids", "attention_mask", "label"]
train_ds.set_format(type="torch", columns=columns)
val_ds.set_format(type="torch", columns=columns)
# Out:
# Map:   0%|          | 0/29356 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7340 [00:00<?, ? examples/s]

# %% [markdown]
# ## 学習設定

# %%
# wandbのログイン
wandb.login(key=userdata.get("WANDB_API_KEY"))
wandb.init(project=CFG.comp_name, name=CFG.exp_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tomokazu_rikioka (tomokazu_rikioka_) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp002/wandb/run-20250911_225258-bkvy1tpj</code>
# Syncing run <strong><a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/bkvy1tpj' target="_blank">ettin-encoder-1b_exp002</a></strong> to <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map</a>
#  View run at <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/bkvy1tpj' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/bkvy1tpj</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/bkvy1tpj?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# モデルの読み込み
model = AutoModelForSequenceClassification.from_pretrained(
    CFG.model_name,
    num_labels=n_classes,
    reference_compile=False,
)
hdim = model.config.hidden_size
model.score = torch.nn.Sequential(
    torch.nn.Dropout(0.1),
    torch.nn.Linear(hdim, hdim // 2),
    torch.nn.Dropout(0.1),
    torch.nn.GELU(),
    torch.nn.Linear(hdim // 2, 2),
).to(CFG.device)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at jhu-clsp/ettin-encoder-1b and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 学習の設定
training_args = TrainingArguments(
    output_dir=CFG.output_dir_path,
    do_train=True,
    do_eval=True,
    eval_strategy="steps",
    save_strategy="steps",
    num_train_epochs=CFG.num_train_epochs,
    per_device_train_batch_size=CFG.per_device_train_batch_size,
    gradient_accumulation_steps=CFG.gradient_accumulation_steps,
    per_device_eval_batch_size=CFG.per_device_eval_batch_size,
    learning_rate=CFG.learning_rate,
    optim=CFG.optim_type,
    lr_scheduler_type=CFG.lr_scheduler_type,
    warmup_steps=CFG.warmup_steps,
    weight_decay=CFG.weight_decay,
    logging_dir=CFG.log_dir_path,
    logging_steps=50,
    save_steps=600,
    eval_steps=300,
    save_total_limit=1,
    metric_for_best_model="map@3",
    greater_is_better=True,
    load_best_model_at_end=True,
    report_to="wandb",
    bf16=True,
    fp16=False,  # KaggleはT4なのでFP16で推論
)

# %%
# カスタムメトリック
def compute_map3(eval_pred):
    logits, labels = eval_pred
    probs = torch.nn.functional.softmax(torch.tensor(logits), dim=-1).numpy()

    top3 = np.argsort(-probs, axis=1)[:, :3]  # トップ3の予測
    match = top3 == labels[:, None]

    # MAP@3を計算
    map3 = 0
    for i in range(len(labels)):
        if match[i, 0]:
            map3 += 1.0
        elif match[i, 1]:
            map3 += 1.0 / 2
        elif match[i, 2]:
            map3 += 1.0 / 3
    return {"map@3": map3 / len(labels)}

# %% [markdown]
# ## モデルの学習

# %%
# トレーナーの設定
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    processing_class=tokenizer,
    compute_metrics=compute_map3,
)
hdim = model.config.hidden_size
model.score = torch.nn.Sequential(
    torch.nn.Dropout(0.1),
    torch.nn.Linear(hdim, hdim // 2),
    torch.nn.Dropout(0.1),
    torch.nn.GELU(),
    torch.nn.Linear(hdim // 2, 2),
).bfloat16().to(CFG.device)

# モデルの学習
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': None, 'bos_token_id': None}.
#     <div>
#
#       <progress value='2754' max='2754' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2754/2754 28:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Map@3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>0.533300</td>
#       <td>0.511312</td>
#       <td>0.903247</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.502600</td>
#       <td>0.415984</td>
#       <td>0.919391</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.399000</td>
#       <td>0.396116</td>
#       <td>0.921730</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.267200</td>
#       <td>0.404784</td>
#       <td>0.930949</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.269000</td>
#       <td>0.345463</td>
#       <td>0.939941</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.292100</td>
#       <td>0.322187</td>
#       <td>0.940350</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.137400</td>
#       <td>0.371699</td>
#       <td>0.940872</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.115000</td>
#       <td>0.389768</td>
#       <td>0.940668</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.102800</td>
#       <td>0.389767</td>
#       <td>0.940804</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2754, training_loss=0.32636335429910657, metrics={'train_runtime': 1701.874, 'train_samples_per_second': 51.748, 'train_steps_per_second': 1.618, 'total_flos': 1.2752528059782144e+17, 'train_loss': 0.32636335429910657, 'epoch': 3.0})

# %% [markdown]
# ## モデルの保存

# %%
trainer.save_model(f"{CFG.output_dir_path}/model")
tokenizer.save_pretrained(f"{CFG.output_dir_path}/tokenizer")
# Out:
# ('output//tokenizer/tokenizer_config.json',
#  'output//tokenizer/special_tokens_map.json',
#  'output//tokenizer/tokenizer.json')

# %%
# WandBのセッションを終了
with wandb.init():
    wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▄▄▄▂▁▃▄▄</td></tr><tr><td>eval/map@3</td><td>▁▄▄▆█████</td></tr><tr><td>eval/runtime</td><td>▁▃▂▇▅▆█▇▇</td></tr><tr><td>eval/samples_per_second</td><td>█▆▇▂▄▃▁▂▂</td></tr><tr><td>eval/steps_per_second</td><td>█▆▇▂▃▃▁▂▂</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/grad_norm</td><td>▇▆▇█▄▆▄▅▃▅▃▅▄▅▂▄▄▄▃▂▃▄▄▃▄▄▁▂▂▃▃▄▁▂▃▂▂▃▁▃</td></tr><tr><td>train/learning_rate</td><td>████████▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>██▇▇▇▆▆▇▆▆▆▆▅▄▄▃▄▄▃▃▃▄▃▃▄▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.38977</td></tr><tr><td>eval/map@3</td><td>0.9408</td></tr><tr><td>eval/runtime</td><td>27.9727</td></tr><tr><td>eval/samples_per_second</td><td>262.398</td></tr><tr><td>eval/steps_per_second</td><td>4.111</td></tr><tr><td>total_flos</td><td>1.2752528059782144e+17</td></tr><tr><td>train/epoch</td><td>3</td></tr><tr><td>train/global_step</td><td>2754</td></tr><tr><td>train/grad_norm</td><td>3.43715</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ettin-encoder-1b_exp002</strong> at: <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/bkvy1tpj' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map/runs/bkvy1tpj</a><br> View project at: <a href='https://wandb.ai/tomokazu_rikioka_/kaggle_map' target="_blank">https://wandb.ai/tomokazu_rikioka_/kaggle_map</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250911_225258-bkvy1tpj/logs</code>
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp002/wandb/run-20250911_232207-w36x56bg</code>
# Syncing run <strong><a href='https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/w36x56bg' target="_blank">chocolate-disco-6</a></strong> to <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized</a>
#  View run at <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/w36x56bg' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/w36x56bg</a>
#  View run <strong style="color:#cdcd00">chocolate-disco-6</strong> at: <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/w36x56bg' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized/runs/w36x56bg</a><br> View project at: <a href='https://wandb.ai/tomokazu_rikioka_/uncategorized' target="_blank">https://wandb.ai/tomokazu_rikioka_/uncategorized</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250911_232207-w36x56bg/logs</code>

# %%
# キャッシュ削除
del model, tokenizer, trainer
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # 結果分析

# %%
# 学習済みモデルの読み込み
model_path = f"{CFG.output_dir_path}/model"
tokenizer_path = f"{CFG.output_dir_path}/tokenizer"

inference_model = AutoModelForSequenceClassification.from_pretrained(
    model_path,
    num_labels=n_classes,
    reference_compile=False,
)
hdim = inference_model.config.hidden_size
inference_model.score = torch.nn.Sequential(
    torch.nn.Dropout(0.1),
    torch.nn.Linear(hdim, hdim // 2),
    torch.nn.Dropout(0.1),
    torch.nn.GELU(),
    torch.nn.Linear(hdim // 2, 2),
).bfloat16().to(CFG.device)
inference_tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

# 推論用のインスタンスを作成
inference_trainer = Trainer(
    model=inference_model,
    processing_class=inference_tokenizer
)

# 検証データの推論実行
inference_model.eval()
start_time = time.time()

val_predictions = inference_trainer.predict(val_ds)
logits = val_predictions.predictions
val_labels = val_predictions.label_ids

# 推論時間を計算
inference_time = time.time() - start_time
print(f"推論時間: {inference_time:.2f}秒")
print(f"サンプル数: {len(val_labels)}個")
print(f"1サンプルあたりの推論時間: {inference_time/len(val_labels)*1000:.2f}ms")

# 確率値に変換
val_probs = torch.nn.functional.softmax(torch.tensor(logits), dim=-1).numpy()

# Top-1精度の計算
val_pred_labels = np.argmax(logits, axis=1)
accuracy = (val_pred_labels == val_labels).mean()
print(f"\nTop-1精度: {accuracy:.4f}")

# MAP@3スコアの計算
map3_score = compute_map3((logits, val_labels))["map@3"]
print(f"MAP@3スコア: {map3_score:.4f}")
# Out:
# Some weights of the model checkpoint at output//model were not used when initializing ModernBertForSequenceClassification: ['score.1.bias', 'score.1.weight', 'score.4.bias', 'score.4.weight']
# - This IS expected if you are initializing ModernBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ModernBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# creating run (0.5s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/drive/MyDrive/Python/kaggle_map/src/ettin-encoder-1b_exp002/wandb/run-20250911_232258-nb98zkeg</code>
# Syncing run <strong><a href='https://wandb.ai/tomokazu_rikioka_/huggingface/runs/nb98zkeg' target="_blank">brisk-sound-6</a></strong> to <a href='https://wandb.ai/tomokazu_rikioka_/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomokazu_rikioka_/huggingface' target="_blank">https://wandb.ai/tomokazu_rikioka_/huggingface</a>
#  View run at <a href='https://wandb.ai/tomokazu_rikioka_/huggingface/runs/nb98zkeg' target="_blank">https://wandb.ai/tomokazu_rikioka_/huggingface/runs/nb98zkeg</a>
# 推論時間: 43.95秒
# サンプル数: 7340個
# 1サンプルあたりの推論時間: 5.99ms
#
# Top-1精度: 0.8871
# MAP@3スコア: 0.9403

# %% [markdown]
# ## 項目別の結果分析

# %%
# Top-3予測の取得
top3_indices = np.argsort(-val_probs, axis=1)[:, :3]
top3_probs = np.take_along_axis(val_probs, top3_indices, axis=1)

# Top-1予測の取得
max_probs = val_probs.max(axis=1)

# %%
# 検証データに必要な情報を追加
val_df_analysis = val_df.copy()
val_df_analysis["pred_label"] = val_pred_labels
val_df_analysis["actual_label"] = val_labels
val_df_analysis["confidence"] = max_probs
val_df_analysis["is_correct"] = (val_pred_labels == val_labels)

# Top-3予測の情報を追加
for i in range(3):
    val_df_analysis[f"top{i+1}_label"] = top3_indices[:, i]
    val_df_analysis[f"top{i+1}_prob"] = top3_probs[:, i]
    val_df_analysis[f"top{i+1}_name"] = [le.inverse_transform([x])[0] for x in top3_indices[:, i]]

# Top-3に正解が含まれているか
val_df_analysis["is_in_top3"] = [label in top3_indices[i] for i, label in enumerate(val_labels)]

# MAP@3スコアを各サンプルごとに計算
def calculate_map3_per_sample(row):
    if row["actual_label"] == row["top1_label"]:
        return 1.0
    elif row["actual_label"] == row["top2_label"]:
        return 1.0 / 2
    elif row["actual_label"] == row["top3_label"]:
        return 1.0 / 3
    else:
        return 0.0

val_df_analysis["map3_score"] = val_df_analysis.apply(calculate_map3_per_sample, axis=1)

# CategoryとMisconceptionを分離
val_df_analysis["actual_category"] = val_df_analysis["target"].apply(lambda x: x.split(":")[0])
val_df_analysis["actual_misconception"] = val_df_analysis["target"].apply(lambda x: x.split(":")[1])
val_df_analysis["pred_category"] = val_df_analysis["top1_name"].apply(lambda x: x.split(":")[0])
val_df_analysis["pred_misconception"] = val_df_analysis["top1_name"].apply(lambda x: x.split(":")[1])

# %% [markdown]
# ### Questionごとの予測確率分布

# %%
question_stats = val_df_analysis.groupby("QuestionId").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "QuestionText": "first",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "label": "Sample_Count"
}).sort_values("MAP@3", ascending=False)

# 結果の表示
question_stats = question_stats.reset_index()
question_stats
# Out:
#     QuestionId     MAP@3  Top1_Accuracy  Top3_Accuracy  Avg_Confidence  \
# 0        31777  0.971530       0.944840       0.998221        0.954795
# 1        32829  0.968677       0.937355       1.000000        0.957590
# 2        31772  0.957305       0.916667       0.998971        0.924251
# 3        33471  0.955232       0.919094       0.993528        0.926366
# 4        33472  0.945833       0.898214       0.994643        0.894218
# 5        89443  0.942171       0.895254       0.993453        0.921663
# 6        31778  0.936584       0.883242       0.994505        0.895385
# 7        91695  0.935824       0.877395       0.996169        0.910890
# 8        32833  0.932904       0.869565       0.996779        0.900193
# 9       109465  0.932540       0.866667       1.000000        0.922191
# 10      104665  0.925926       0.866667       0.985185        0.895631
# 11       31774  0.923756       0.858748       0.996790        0.885180
# 12       32835  0.921316       0.856223       0.989270        0.890316
# 13       76870  0.913502       0.827004       1.000000        0.874986
# 14       33474  0.894712       0.796034       0.994334        0.866701
#
#                                          QuestionText  Sample_Count
# 0   A box contains \( 120 \) counters. The counter...           562
# 1         \( 2 y=24 \) What is the value of \( y \) ?           431
# 2   What fraction of the shape is not shaded? Give...           972
# 3   A bag contains \( 24 \) yellow and green balls...           309
# 4                      \( \frac{1}{3}+\frac{2}{5}= \)           560
# 5   What number belongs in the box?\n\(\n(-8)-(-5)...           611
# 6   \( \frac{A}{10}=\frac{9}{15} \) What is the va...           728
# 7   Dots have been arranged in these patterns: [Im...           522
# 8                Calculate \( \frac{2}{3} \times 5 \)           621
# 9   The probability of an event occurring is \( 0....           210
# 10  It takes \( 3 \) people a total of \( 192 \) h...           135
# 11                 Calculate \( \frac{1}{2} \div 6 \)           623
# 12                      Which number is the greatest?           466
# 13  This is part of a regular polygon. How many si...           237
# 14  Sally has \( \frac{2}{3} \) of a whole cake in...           353

# %% [markdown]
# ### Categoryごとの予測確率分布

# %%
category_stats = val_df_analysis.groupby("actual_category").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "label": "Sample_Count"
}).sort_values("MAP@3", ascending=False)

# 結果の表示
category_stats = category_stats.reset_index()
category_stats
# Out:
#        actual_category     MAP@3  Top1_Accuracy  Top3_Accuracy  \
# 0         True_Correct  0.971161       0.942886       0.999662
# 1        False_Neither  0.952217       0.905963       0.999235
# 2  False_Misconception  0.924635       0.860539       0.993133
# 3         True_Neither  0.898482       0.796964       1.000000
# 4        False_Correct  0.709302       0.558140       0.883721
# 5   True_Misconception  0.664659       0.518072       0.879518
#
#    Avg_Confidence  Sample_Count
# 0        0.932904          2959
# 1        0.922635          1308
# 2        0.908397          1893
# 3        0.843524          1054
# 4        0.870469            43
# 5        0.783723            83

# %% [markdown]
# ### Misconceptionごとの予測確率分布

# %%
misconception_stats = val_df_analysis.groupby("actual_misconception").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "label": "Sample_Count"
}).sort_values("MAP@3", ascending=False)

# 結果の表示
misconception_stats = misconception_stats.reset_index()
display(misconception_stats.head())
display(misconception_stats.tail())
# Out:
#   actual_misconception     MAP@3  Top1_Accuracy  Top3_Accuracy  \
# 0             Interior  1.000000       1.000000       1.000000
# 1       Wrong_Fraction  0.981818       0.963636       1.000000
# 2             Additive  0.977718       0.957219       1.000000
# 3         Adding_terms  0.973684       0.947368       1.000000
# 4       Wrong_fraction  0.962302       0.940476       0.988095
#
#    Avg_Confidence  Sample_Count
# 0        0.977197            10
# 1        0.942890            55
# 2        0.948712           187
# 3        0.965401            19
# 4        0.939730            84
#                       actual_misconception     MAP@3  Top1_Accuracy  \
# 31  Incorrect_equivalent_fraction_addition  0.500000            0.5
# 32                         Wrong_Operation  0.500000            0.0
# 33                               Certainty  0.444444            0.0
# 34                        Longer_is_bigger  0.400000            0.2
# 35                       Shorter_is_bigger  0.291667            0.0
#
#     Top3_Accuracy  Avg_Confidence  Sample_Count
# 31           0.50        0.756055             2
# 32           1.00        0.877723             1
# 33           1.00        0.782741             3
# 34           0.60        0.755129             5
# 35           0.75        0.779463             4

# %% [markdown]
# ### ラベル（Category:Misconception）ごとの予測確率分布

# %%
label_level_stats = val_df_analysis.groupby("target").agg({
    "map3_score": "mean",
    "is_correct": "mean",
    "is_in_top3": "mean",
    "confidence": "mean",
    "top1_prob": "mean",
    "top2_prob": "mean",
    "top3_prob": "mean",
    "label": "count"
}).rename(columns={
    "map3_score": "MAP@3",
    "is_correct": "Top1_Accuracy",
    "is_in_top3": "Top3_Accuracy",
    "confidence": "Avg_Confidence",
    "top1_prob": "Avg_Top1_Prob",
    "top2_prob": "Avg_Top2_Prob",
    "top3_prob": "Avg_Top3_Prob",
    "label": "Sample_Count"
}).sort_values('MAP@3', ascending=False)

# 結果を表示
label_level_stats = label_level_stats.reset_index()
display(label_level_stats.head())
display(label_level_stats.tail())
# Out:
#                                               target     MAP@3  Top1_Accuracy  \
# 0  False_Misconception:Incorrect_equivalent_fract...  1.000000       1.000000
# 1                       False_Misconception:Interior  1.000000       1.000000
# 2                       False_Misconception:Additive  0.985102       0.972067
# 3                 False_Misconception:Wrong_Fraction  0.981818       0.963636
# 4                 False_Misconception:Wrong_fraction  0.973896       0.951807
#
#    Top3_Accuracy  Avg_Confidence  Avg_Top1_Prob  Avg_Top2_Prob  Avg_Top3_Prob  \
# 0            1.0        0.823637       0.823637       0.108038       0.041006
# 1            1.0        0.977197       0.977197       0.019565       0.002778
# 2            1.0        0.960658       0.960658       0.033748       0.003799
# 3            1.0        0.942890       0.942890       0.047599       0.008184
# 4            1.0        0.940982       0.940982       0.056068       0.001789
#
#    Sample_Count
# 0             1
# 1            10
# 2           179
# 3            55
# 4            83
#                                                target  MAP@3  Top1_Accuracy  \
# 55  True_Misconception:Incorrect_equivalent_fracti...    0.0            0.0
# 56                        True_Misconception:Positive    0.0            0.0
# 57                     True_Misconception:Subtraction    0.0            0.0
# 58                  True_Misconception:Wrong_fraction    0.0            0.0
# 59            True_Misconception:Whole_numbers_larger    0.0            0.0
#
#     Top3_Accuracy  Avg_Confidence  Avg_Top1_Prob  Avg_Top2_Prob  \
# 55            0.0        0.688474       0.688474       0.278169
# 56            0.0        0.687408       0.687408       0.305036
# 57            0.0        0.878976       0.878976       0.076804
# 58            0.0        0.835782       0.835782       0.120406
# 59            0.0        0.980046       0.980046       0.009608
#
#     Avg_Top3_Prob  Sample_Count
# 55       0.003727             1
# 56       0.001190             1
# 57       0.007970             1
# 58       0.009285             1
# 59       0.007029             1

# %%
# CSVで保存
question_stats.to_csv(f"{CFG.output_dir_path}/question_statistics.csv")
category_stats.to_csv(f"{CFG.output_dir_path}/category_statistics.csv")
misconception_stats.to_csv(f"{CFG.output_dir_path}/misconception_statistics.csv")
label_level_stats.to_csv(f"{CFG.output_dir_path}/label_level_statistics.csv")

# %%
# 検証データの全レコードに予測結果を付与したデータフレームを保存
val_df_with_predictions = val_df_analysis[[
    "row_id", "QuestionId", "QuestionText", "MC_Answer", "StudentExplanation",
    "Category", "Misconception", "target", "label", "actual_label",
    "pred_label", "confidence", "is_correct", "is_in_top3", "map3_score",
    "top1_label", "top1_prob", "top1_name",
    "top2_label", "top2_prob", "top2_name",
    "top3_label", "top3_prob", "top3_name",
    "actual_category", "actual_misconception",
    "pred_category", "pred_misconception"
]]

val_df_with_predictions.to_csv(f"{CFG.output_dir_path}/val_predictions_full.csv", index=False)

# %% [markdown]
# ## 誤分類サンプルの分析

# %% [markdown]
# ### Top-1で誤分類したサンプル

# %%
# 誤分類サンプルの特定
misclassified_mask = (val_pred_labels != val_labels)
misclassified_indices = np.where(misclassified_mask)[0]

print(f"誤分類サンプル数: {len(misclassified_indices)} / {len(val_labels)} ({len(misclassified_indices)/len(val_labels)*100:.1f}%)")

# 確信度の低いサンプルトップ10を表示
low_confidence_indices = np.argsort(max_probs)[:10]
print(f"\n=== 確信度の低いサンプル（上位10件）===")

for i, idx in enumerate(low_confidence_indices):
    actual_label = val_labels[idx]
    pred_label = val_pred_labels[idx]
    confidence = max_probs[idx]
    is_correct = "正解" if actual_label == pred_label else "誤り"

    actual_name = le.inverse_transform([actual_label])[0]
    pred_name = le.inverse_transform([pred_label])[0]

    print(f"#{i+1:2d} 確信度={confidence:.3f} ({is_correct})")
    print(f"    実際: {actual_name}")
    print(f"    予測: {pred_name}")
    print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
    print(f"    Top-3確率: {top3_probs[idx]}")
    print()

# 誤分類の中で確信度の高いサンプルを表示（モデルが自信を持って間違えたケース）
if len(misclassified_indices) > 0:
    misclassified_confidences = max_probs[misclassified_indices]
    high_confidence_wrong_indices = misclassified_indices[np.argsort(-misclassified_confidences)[:10]]

    print(f"=== 高確信度で誤分類したサンプル（上位10件）===")
    for i, idx in enumerate(high_confidence_wrong_indices):
        actual_label = val_labels[idx]
        pred_label = val_pred_labels[idx]
        confidence = max_probs[idx]

        actual_name = le.inverse_transform([actual_label])[0]
        pred_name = le.inverse_transform([pred_label])[0]

        print(f"#{i+1} 確信度={confidence:.3f}")
        print(f"    実際: {actual_name}")
        print(f"    予測: {pred_name}")
        print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
        print(f"    Top-3確率: {top3_probs[idx]}")
        print()
# Out:
# 誤分類サンプル数: 829 / 7340 (11.3%)
#
# === 確信度の低いサンプル（上位10件）===
# # 1 確信度=0.340 (誤り)
#     実際: True_Neither:NA
#     予測: True_Misconception:Shorter_is_bigger
#     Top-3予測: ['True_Misconception:Shorter_is_bigger', 'True_Neither:NA', 'True_Correct:NA']
#     Top-3確率: [0.34039003 0.34039003 0.25693986]
#
# # 2 確信度=0.354 (正解)
#     実際: True_Neither:NA
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Misconception:Wrong_term', 'True_Correct:NA']
#     Top-3確率: [0.35363683 0.2841552  0.17781976]
#
# # 3 確信度=0.376 (誤り)
#     実際: False_Misconception:Mult
#     予測: False_Misconception:SwapDividend
#     Top-3予測: ['False_Misconception:SwapDividend', 'False_Neither:NA', 'False_Misconception:Mult']
#     Top-3確率: [0.37625736 0.36468112 0.23545586]
#
# # 4 確信度=0.377 (正解)
#     実際: False_Neither:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:SwapDividend', 'False_Misconception:FlipChange']
#     Top-3確率: [0.3769205  0.33263117 0.17804463]
#
# # 5 確信度=0.380 (正解)
#     実際: False_Misconception:SwapDividend
#     予測: False_Misconception:SwapDividend
#     Top-3予測: ['False_Misconception:SwapDividend', 'False_Misconception:FlipChange', 'False_Neither:NA']
#     Top-3確率: [0.37971857 0.36803585 0.23031096]
#
# # 6 確信度=0.403 (誤り)
#     実際: False_Neither:NA
#     予測: False_Misconception:Mult
#     Top-3予測: ['False_Misconception:Mult', 'False_Misconception:SwapDividend', 'False_Neither:NA']
#     Top-3確率: [0.40305027 0.2948779  0.28580546]
#
# # 7 確信度=0.410 (誤り)
#     実際: False_Neither:NA
#     予測: False_Misconception:Mult
#     Top-3予測: ['False_Misconception:Mult', 'False_Neither:NA', 'False_Misconception:SwapDividend']
#     Top-3確率: [0.41004375 0.30951726 0.26474413]
#
# # 8 確信度=0.424 (誤り)
#     実際: True_Misconception:Irrelevant
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Misconception:Irrelevant', 'True_Correct:NA']
#     Top-3確率: [0.42388478 0.28236812 0.25709912]
#
# # 9 確信度=0.433 (正解)
#     実際: True_Correct:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Irrelevant']
#     Top-3確率: [0.43318525 0.337365   0.21111763]
#
# #10 確信度=0.434 (正解)
#     実際: False_Misconception:Whole_numbers_larger
#     予測: False_Misconception:Whole_numbers_larger
#     Top-3予測: ['False_Misconception:Whole_numbers_larger', 'False_Neither:NA', 'False_Misconception:Shorter_is_bigger']
#     Top-3確率: [0.43411332 0.43411332 0.0909951 ]
#
# === 高確信度で誤分類したサンプル（上位10件）===
# #1 確信度=0.998
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Incomplete']
#     Top-3確率: [9.9836510e-01 1.5486275e-03 8.5164484e-06]
#
# #2 確信度=0.997
#     実際: False_Misconception:Irrelevant
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'True_Neither:NA', 'False_Misconception:Additive']
#     Top-3確率: [9.9732852e-01 9.0944592e-04 3.6744936e-04]
#
# #3 確信度=0.996
#     実際: False_Misconception:Unknowable
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Unknowable', 'False_Misconception:Positive']
#     Top-3確率: [9.9647528e-01 2.6293176e-03 1.6548071e-04]
#
# #4 確信度=0.996
#     実際: False_Misconception:Incomplete
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Incomplete', 'False_Misconception:WNB']
#     Top-3確率: [9.9605089e-01 3.1702118e-03 1.7885111e-04]
#
# #5 確信度=0.996
#     実際: False_Misconception:Unknowable
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Unknowable', 'False_Misconception:Definition']
#     Top-3確率: [9.9583435e-01 2.6276265e-03 1.7603999e-04]
#
# #6 確信度=0.995
#     実際: False_Correct:NA
#     予測: False_Misconception:Incomplete
#     Top-3予測: ['False_Misconception:Incomplete', 'False_Neither:NA', 'False_Correct:NA']
#     Top-3確率: [9.9537754e-01 4.3302365e-03 1.3491264e-04]
#
# #7 確信度=0.995
#     実際: False_Correct:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Irrelevant', 'False_Misconception:Incomplete']
#     Top-3確率: [9.9529570e-01 2.3176179e-03 8.2637212e-04]
#
# #8 確信度=0.995
#     実際: False_Misconception:Unknowable
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Unknowable', 'False_Misconception:Positive']
#     Top-3確率: [9.9490947e-01 2.8832029e-03 4.3529851e-04]
#
# #9 確信度=0.995
#     実際: False_Misconception:Whole_numbers_larger
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Whole_numbers_larger', 'False_Misconception:Longer_is_bigger']
#     Top-3確率: [9.9476480e-01 6.5336545e-04 6.5336545e-04]
#
# #10 確信度=0.995
#     実際: True_Neither:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Shorter_is_bigger']
#     Top-3確率: [9.9453366e-01 5.2188337e-03 4.8063797e-05]

# %% [markdown]
# ### Top-3で誤分類したサンプル

# %%
# 誤分類サンプルの特定
misclassified_mask = [val_labels[i] not in top3_indices[i] for i in range(len(val_labels))]
misclassified_indices = np.where(misclassified_mask)[0]

print(f"誤分類サンプル数: {len(misclassified_indices)} / {len(val_labels)} "
      f"({len(misclassified_indices)/len(val_labels)*100:.1f}%)")

# 確信度の低いサンプルトップ10を表示
low_confidence_indices = np.argsort(max_probs)[:10]
print(f"\n=== 確信度の低いサンプル（上位10件）===")

for i, idx in enumerate(low_confidence_indices):
    actual_label = val_labels[idx]
    pred_label = val_pred_labels[idx]
    confidence = max_probs[idx]
    is_correct = "正解" if actual_label in top3_indices[idx] else "誤り"

    actual_name = le.inverse_transform([actual_label])[0]
    pred_name = le.inverse_transform([pred_label])[0]

    print(f"#{i+1:2d} 確信度={confidence:.3f} ({is_correct})")
    print(f"    実際: {actual_name}")
    print(f"    予測: {pred_name}")
    print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
    print(f"    Top-3確率: {top3_probs[idx]}")
    print()

# 誤分類の中で確信度の高いサンプルを表示（モデルが自信を持って間違えたケース）
if len(misclassified_indices) > 0:
    misclassified_confidences = max_probs[misclassified_indices]
    high_confidence_wrong_indices = misclassified_indices[np.argsort(-misclassified_confidences)[:10]]

    print(f"=== 高確信度で誤分類したサンプル（上位10件）===")
    for i, idx in enumerate(high_confidence_wrong_indices):
        actual_label = val_labels[idx]
        pred_label = val_pred_labels[idx]
        confidence = max_probs[idx]

        actual_name = le.inverse_transform([actual_label])[0]
        pred_name = le.inverse_transform([pred_label])[0]

        print(f"#{i+1} 確信度={confidence:.3f}")
        print(f"    実際: {actual_name}")
        print(f"    予測: {pred_name}")
        print(f"    Top-3予測: {[le.inverse_transform([x])[0] for x in top3_indices[idx]]}")
        print(f"    Top-3確率: {top3_probs[idx]}")
        print()
# Out:
# 誤分類サンプル数: 30 / 7340 (0.4%)
#
# === 確信度の低いサンプル（上位10件）===
# # 1 確信度=0.340 (正解)
#     実際: True_Neither:NA
#     予測: True_Misconception:Shorter_is_bigger
#     Top-3予測: ['True_Misconception:Shorter_is_bigger', 'True_Neither:NA', 'True_Correct:NA']
#     Top-3確率: [0.34039003 0.34039003 0.25693986]
#
# # 2 確信度=0.354 (正解)
#     実際: True_Neither:NA
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Misconception:Wrong_term', 'True_Correct:NA']
#     Top-3確率: [0.35363683 0.2841552  0.17781976]
#
# # 3 確信度=0.376 (正解)
#     実際: False_Misconception:Mult
#     予測: False_Misconception:SwapDividend
#     Top-3予測: ['False_Misconception:SwapDividend', 'False_Neither:NA', 'False_Misconception:Mult']
#     Top-3確率: [0.37625736 0.36468112 0.23545586]
#
# # 4 確信度=0.377 (正解)
#     実際: False_Neither:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:SwapDividend', 'False_Misconception:FlipChange']
#     Top-3確率: [0.3769205  0.33263117 0.17804463]
#
# # 5 確信度=0.380 (正解)
#     実際: False_Misconception:SwapDividend
#     予測: False_Misconception:SwapDividend
#     Top-3予測: ['False_Misconception:SwapDividend', 'False_Misconception:FlipChange', 'False_Neither:NA']
#     Top-3確率: [0.37971857 0.36803585 0.23031096]
#
# # 6 確信度=0.403 (正解)
#     実際: False_Neither:NA
#     予測: False_Misconception:Mult
#     Top-3予測: ['False_Misconception:Mult', 'False_Misconception:SwapDividend', 'False_Neither:NA']
#     Top-3確率: [0.40305027 0.2948779  0.28580546]
#
# # 7 確信度=0.410 (正解)
#     実際: False_Neither:NA
#     予測: False_Misconception:Mult
#     Top-3予測: ['False_Misconception:Mult', 'False_Neither:NA', 'False_Misconception:SwapDividend']
#     Top-3確率: [0.41004375 0.30951726 0.26474413]
#
# # 8 確信度=0.424 (正解)
#     実際: True_Misconception:Irrelevant
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Misconception:Irrelevant', 'True_Correct:NA']
#     Top-3確率: [0.42388478 0.28236812 0.25709912]
#
# # 9 確信度=0.433 (正解)
#     実際: True_Correct:NA
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Irrelevant']
#     Top-3確率: [0.43318525 0.337365   0.21111763]
#
# #10 確信度=0.434 (正解)
#     実際: False_Misconception:Whole_numbers_larger
#     予測: False_Misconception:Whole_numbers_larger
#     Top-3予測: ['False_Misconception:Whole_numbers_larger', 'False_Neither:NA', 'False_Misconception:Shorter_is_bigger']
#     Top-3確率: [0.43411332 0.43411332 0.0909951 ]
#
# === 高確信度で誤分類したサンプル（上位10件）===
# #1 確信度=0.997
#     実際: False_Misconception:Irrelevant
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'True_Neither:NA', 'False_Misconception:Additive']
#     Top-3確率: [9.9732852e-01 9.0944592e-04 3.6744936e-04]
#
# #2 確信度=0.995
#     実際: False_Correct:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Irrelevant', 'False_Misconception:Incomplete']
#     Top-3確率: [9.9529570e-01 2.3176179e-03 8.2637212e-04]
#
# #3 確信度=0.991
#     実際: False_Misconception:Longer_is_bigger
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Ignores_zeroes', 'False_Misconception:Shorter_is_bigger']
#     Top-3確率: [9.914725e-01 4.591428e-03 8.900890e-04]
#
# #4 確信度=0.988
#     実際: True_Misconception:Adding_across
#     予測: True_Correct:NA
#     Top-3予測: ['True_Correct:NA', 'True_Neither:NA', 'True_Misconception:Denominator-only_change']
#     Top-3確率: [9.8761219e-01 1.0971380e-02 4.5284294e-04]
#
# #5 確信度=0.987
#     実際: False_Correct:NA
#     予測: False_Misconception:Wrong_fraction
#     Top-3予測: ['False_Misconception:Wrong_fraction', 'False_Neither:NA', 'False_Misconception:Irrelevant']
#     Top-3確率: [9.8650867e-01 1.2812511e-02 2.7435622e-04]
#
# #6 確信度=0.982
#     実際: False_Misconception:Whole_numbers_larger
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Longer_is_bigger', 'False_Correct:NA']
#     Top-3確率: [0.9816095  0.00556957 0.00348535]
#
# #7 確信度=0.980
#     実際: True_Misconception:Whole_numbers_larger
#     予測: True_Neither:NA
#     Top-3予測: ['True_Neither:NA', 'True_Correct:NA', 'True_Misconception:Shorter_is_bigger']
#     Top-3確率: [0.98004603 0.00960803 0.00702939]
#
# #8 確信度=0.977
#     実際: False_Misconception:WNB
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Incomplete', 'False_Misconception:Adding_across']
#     Top-3確率: [0.9766176  0.01119363 0.00220416]
#
# #9 確信度=0.976
#     実際: False_Correct:NA
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Wrong_term', 'False_Misconception:Adding_terms']
#     Top-3確率: [0.97606206 0.00580388 0.0051219 ]
#
# #10 確信度=0.969
#     実際: False_Misconception:Wrong_term
#     予測: False_Neither:NA
#     Top-3予測: ['False_Neither:NA', 'False_Misconception:Firstterm', 'False_Correct:NA']
#     Top-3確率: [0.968567   0.01517376 0.00892019]
